# %% [markdown]
# <a href="https://colab.research.google.com/github/BIGBULL777/NLP--AB/blob/main/NLP_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install WordCloud
# import WordCloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = "There are many variations of passages of Lorem Ipsum available, but the majority have suffered alteration in some form, by injected humour, or randomised words which don't look even slightly believable. If you are going to use a passage of Lorem Ipsum, you need to be sure there isn't anything embarrassing hidden in the middle of text. All the Lorem Ipsum generators on the Internet tend to repeat predefined chunks as necessary, making this the first true generator on the Internet. It uses a dictionary of over 200 Latin words, combined with a handful of model sentence structures, to generate Lorem Ipsum which looks reasonable. The generated Lorem Ipsum is therefore always free from repetition, injected humour, or non-characteristic words etc."

# %%
wordcloud  = WordCloud().generate(text)

# %%
plt.figure(figsize= (12,12))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
#1mport required Libraries :
import numpy as np
from PIL import Image
from wordcloud import WordCloud
#Here we are going to use a circle image as mask .
char_mask = np.array(Image.open("/content/Picture1.png"))

wc = WordCloud(background_color = "black",mask = char_mask).generate(text)
#Plot the wordcloud .
plt.figure(figsize = (12,12))
plt. imshow(wc)
# remove the axis value .
plt. axis ("off")
plt. show()

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
word_list = ['Study','Studying','Studies','Studied']
for i in word_list:
  print(porter.stem(i))
# Out:
# studi
# studi
# studi
# studi

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
word_list = ['leaves','decreases','Studies','plays']
for i in word_list:
  print(porter.stem(i))
# Out:
# leav
# decreas
# studi
# play

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer('english')
word_list = ['Study','Studying','Studies','Studied']
for i in word_list:
  print(snowball.stem(i))
# Out:
# studi
# studi
# studi
# studi

# %%
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
# from nltk.stem import SnowballStemmer,DawsonStemmer
# Dawson = DawsonStemmer()
# word_list = ['Study','Studying','Studies','Studied']
# for i in word_list:
#   print(Dawson.stem(i))
